# %% [markdown]
# <a href="https://colab.research.google.com/github/ivandwinugraha/KecerdasanBuatan/blob/main/neural_network/neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Download dataset
#!wget --no-check-certificate \
   # https://drive.google.com/file/d/1bg65Lq5l0GEla0fXr-B6K-0B8Y2OzG_S/view?usp=sharing \
   # -O /tmp/jambu_jeruk.zip

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import zipfile

local_zip = '/content/drive/MyDrive/Colab Notebooks/jambubiji_and_jeruknipis.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %%
base_dir = '/tmp/jambubiji_and_jeruknipis'

train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

train_jambubiji_dir = os.path.join(train_dir, 'Psidium Guajava_JambuBiji')
train_jeruknipis_dir = os.path.join(train_dir, 'Citrus Aurantifolia_JerukNipis')

validation_jeruknipis_dir = os.path.join(validation_dir, 'Citrus Aurantifolia_JerukNipis')
validation_jambubiji_dir = os.path.join(validation_dir, 'Psidium Guajava_JambuBiji')

# %%
# Cek penamaan image yang ada di folder train_cats_dir dan train_dogs_dir
print(os.listdir(train_jambubiji_dir)[:10])
print(os.listdir(train_jeruknipis_dir)[:10])
# Out:
# ['PG-038.jpg', 'PG-003.jpg', 'PG-026.jpg', 'PG-050.jpg', 'PG-036.jpg', 'PG-043.jpg', 'PG-034.jpg', 'PG-008.jpg', 'PG-040.jpg', 'PG-049.jpg']
# ['CS-058.jpg', 'CS-052.jpg', 'CS-054.jpg', 'CS-067.jpg', 'CS-080.jpg', 'CS-071.jpg', 'CS-083.jpg', 'CS-072.jpg', 'CS-086.jpg', 'CS-066.jpg']

# %%
# Cek jumlah data train dan data validation
print('total training jeruk nipis images:', len(os.listdir(train_jeruknipis_dir)))
print('total training jambu biji images:', len(os.listdir(train_jambubiji_dir)))
print('total validation jeruk nipis images:', len(os.listdir(validation_jeruknipis_dir)))
print('total validation jambu biji images:', len(os.listdir(validation_jambubiji_dir)))
# Out:
# total training jeruk nipis images: 50
# total training jambu biji images: 50
# total validation jeruk nipis images: 10
# total validation jambu biji images: 10

# %%
# Tampilkan 8 image per kelas dengan ukuran 4x4 

# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

nrows = 4
ncols = 4

pic_index = 0

fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

pic_index += 8
next_jeruknipis_pix = [os.path.join(train_jeruknipis_dir, fname) 
                for fname in os.listdir(train_jeruknipis_dir)[pic_index-8:pic_index]]
next_jambubiji_pix = [os.path.join(train_jambubiji_dir, fname) 
                for fname in os.listdir(train_jambubiji_dir)[pic_index-8:pic_index]]

for i, img_path in enumerate(next_jeruknipis_pix+next_jambubiji_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %%
import cv2
import numpy as np

# Gather data train
train_data = []
train_label = []
for r, d, f in os.walk(train_dir):
    for file in f:
        if ".jpg" in file:
            imagePath = os.path.join(r, file)
            image = cv2.imread(imagePath)
            image = cv2.resize(image, (150,150))
            train_data.append(image)
            label = imagePath.split(os.path.sep)[-2]
            train_label.append(label)

train_data = np.array(train_data)
train_label = np.array(train_label)

# %%
# Gather data validation
val_data = []
val_label = []
for r, d, f in os.walk(validation_dir):
    for file in f:
        if ".jpg" in file:
            imagePath = os.path.join(r, file)
            image = cv2.imread(imagePath)
            image = cv2.resize(image, (150,150))
            val_data.append(image)
            label = imagePath.split(os.path.sep)[-2]
            val_label.append(label)

val_data = np.array(val_data)
val_label = np.array(val_label)

# %% [markdown]
# <h3>Data Preprocessing</h3>

# %%
# Tampilkan shape dari data train dan data validation
print("Train Data = ", train_data.shape)
print("Train Label = ", train_label.shape)
print("Validation Data = ", val_data.shape)
print("Validation Label = ", val_label.shape)
# Out:
# Train Data =  (100, 150, 150, 3)
# Train Label =  (100,)
# Validation Data =  (10, 150, 150, 3)
# Validation Label =  (10,)

# %%
# Normalisasi dataset
print("Data sebelum di-normalisasi ", train_data[0][0][0])

x_train = train_data.astype('float32') / 255.0
x_val = val_data.astype('float32') / 255.0
print("Data setelah di-normalisasi ", x_train[0][0][0])
# Out:
# Data sebelum di-normalisasi  [255 255 255]
# Data setelah di-normalisasi  [1. 1. 1.]

# %%
# Transformasi label encoder
from sklearn.preprocessing import LabelEncoder

print("Label sebelum di-encoder ", train_label[995:1005])

lb = LabelEncoder()
y_train = lb.fit_transform(train_label)
y_val = lb.fit_transform(val_label)

print("Label setelah di-encoder ", y_train[995:1005])
# Out:
# Label sebelum di-encoder  []
# Label setelah di-encoder  []

# %% [markdown]
# <h3>Definisikan Model</h3>

# %%
from tensorflow.keras import layers
from tensorflow.keras import Model

# %%
# Buat model dengan 1 input layer, 1 hidden layer, dan 1 output layer
img_input = layers.Input(shape=(150, 150, 3)) # layer input
x = layers.Flatten()(img_input) # ubah dari matriks 150x150x3 menjadi vektor
x = layers.Dense(128, activation='relu')(x) # hidden layer 1 dengan 128 neuron
output = layers.Dense(1, activation='sigmoid')(x) # output layer dengan 1 neuron (binary)

# Definisikan modelnya
model = Model(img_input, output)

# %%
# Tampilkan model summary
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  flatten (Flatten)           (None, 67500)             0
#
#  dense (Dense)               (None, 128)               8640128
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 8,640,257
# Trainable params: 8,640,257
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

# Compile model
model.compile(loss='binary_crossentropy',
              optimizer=Adam(lr=0.001),
              metrics=['acc'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
H = model.fit(x_train, y_train, batch_size=20, epochs=50, validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 0s 72ms/step - loss: 6.4781e-06 - acc: 1.0000 - val_loss: 2.6096e-05 - val_acc: 1.0000
# Epoch 2/50
# 5/5 [==============================] - 0s 65ms/step - loss: 6.3752e-06 - acc: 1.0000 - val_loss: 2.5667e-05 - val_acc: 1.0000
# Epoch 3/50
# 5/5 [==============================] - 0s 70ms/step - loss: 6.2715e-06 - acc: 1.0000 - val_loss: 2.5252e-05 - val_acc: 1.0000
# Epoch 4/50
# 5/5 [==============================] - 0s 66ms/step - loss: 6.1814e-06 - acc: 1.0000 - val_loss: 2.4817e-05 - val_acc: 1.0000
# Epoch 5/50
# 5/5 [==============================] - 0s 67ms/step - loss: 6.0644e-06 - acc: 1.0000 - val_loss: 2.4428e-05 - val_acc: 1.0000
# Epoch 6/50
# 5/5 [==============================] - 0s 66ms/step - loss: 5.9746e-06 - acc: 1.0000 - val_loss: 2.4031e-05 - val_acc: 1.0000
# Epoch 7/50
# 5/5 [==============================] - 0s 69ms/step - loss: 5.8721e-06 - acc: 1.0000 - val_loss: 2.3660e-05 - val_acc: 1.0000
# Epoch 8/50
# 5/5 [==============================] - 0s 68ms/step - loss: 5.8082e-06 - acc: 1.0000 - val_loss: 2.3241e-05 - val_acc: 1.0000
# Epoch 9/50
# 5/5 [==============================] - 0s 64ms/step - loss: 5.7067e-06 - acc: 1.0000 - val_loss: 2.2851e-05 - val_acc: 1.0000
# Epoch 10/50
# 5/5 [==============================] - 0s 67ms/step - loss: 5.6038e-06 - acc: 1.0000 - val_loss: 2.2500e-05 - val_acc: 1.0000
# Epoch 11/50
# 5/5 [==============================] - 0s 71ms/step - loss: 5.5039e-06 - acc: 1.0000 - val_loss: 2.2185e-05 - val_acc: 1.0000
# Epoch 12/50
# 5/5 [==============================] - 0s 65ms/step - loss: 5.4508e-06 - acc: 1.0000 - val_loss: 2.1811e-05 - val_acc: 1.0000
# Epoch 13/50
# 5/5 [==============================] - 0s 64ms/step - loss: 5.3644e-06 - acc: 1.0000 - val_loss: 2.1452e-05 - val_acc: 1.0000
# Epoch 14/50
# 5/5 [==============================] - 0s 69ms/step - loss: 5.2719e-06 - acc: 1.0000 - val_loss: 2.1119e-05 - val_acc: 1.0000
# Epoch 15/50
# 5/5 [==============================] - 0s 67ms/step - loss: 5.1882e-06 - acc: 1.0000 - val_loss: 2.0804e-05 - val_acc: 1.0000
# Epoch 16/50
# 5/5 [==============================] - 0s 67ms/step - loss: 5.1019e-06 - acc: 1.0000 - val_loss: 2.0514e-05 - val_acc: 1.0000
# Epoch 17/50
# 5/5 [==============================] - 0s 68ms/step - loss: 5.0437e-06 - acc: 1.0000 - val_loss: 2.0193e-05 - val_acc: 1.0000
# Epoch 18/50
# 5/5 [==============================] - 0s 66ms/step - loss: 4.9637e-06 - acc: 1.0000 - val_loss: 1.9890e-05 - val_acc: 1.0000
# Epoch 19/50
# 5/5 [==============================] - 0s 63ms/step - loss: 4.8948e-06 - acc: 1.0000 - val_loss: 1.9587e-05 - val_acc: 1.0000
# Epoch 20/50
# 5/5 [==============================] - 0s 68ms/step - loss: 4.8378e-06 - acc: 1.0000 - val_loss: 1.9269e-05 - val_acc: 1.0000
# Epoch 21/50
# 5/5 [==============================] - 0s 65ms/step - loss: 4.7463e-06 - acc: 1.0000 - val_loss: 1.8995e-05 - val_acc: 1.0000
# Epoch 22/50
# 5/5 [==============================] - 0s 64ms/step - loss: 4.6729e-06 - acc: 1.0000 - val_loss: 1.8737e-05 - val_acc: 1.0000
# Epoch 23/50
# 5/5 [==============================] - 0s 66ms/step - loss: 4.6224e-06 - acc: 1.0000 - val_loss: 1.8454e-05 - val_acc: 1.0000
# Epoch 24/50
# 5/5 [==============================] - 0s 65ms/step - loss: 4.5526e-06 - acc: 1.0000 - val_loss: 1.8184e-05 - val_acc: 1.0000
# Epoch 25/50
# 5/5 [==============================] - 0s 66ms/step - loss: 4.4737e-06 - acc: 1.0000 - val_loss: 1.7954e-05 - val_acc: 1.0000
# Epoch 26/50
# 5/5 [==============================] - 0s 70ms/step - loss: 4.4304e-06 - acc: 1.0000 - val_loss: 1.7690e-05 - val_acc: 1.0000
# Epoch 27/50
# 5/5 [==============================] - 0s 64ms/step - loss: 4.3604e-06 - acc: 1.0000 - val_loss: 1.7447e-05 - val_acc: 1.0000
# Epoch 28/50
# 5/5 [==============================] - 0s 67ms/step - loss: 4.3094e-06 - acc: 1.0000 - val_loss: 1.7193e-05 - val_acc: 1.0000
# Epoch 29/50
# 5/5 [==============================] - 0s 66ms/step - loss: 4.2403e-06 - acc: 1.0000 - val_loss: 1.6963e-05 - val_acc: 1.0000
# Epoch 30/50
# 5/5 [==============================] - 0s 66ms/step - loss: 4.1853e-06 - acc: 1.0000 - val_loss: 1.6733e-05 - val_acc: 1.0000
# Epoch 31/50
# 5/5 [==============================] - 0s 63ms/step - loss: 4.1390e-06 - acc: 1.0000 - val_loss: 1.6490e-05 - val_acc: 1.0000
# Epoch 32/50
# 5/5 [==============================] - 0s 66ms/step - loss: 4.0714e-06 - acc: 1.0000 - val_loss: 1.6276e-05 - val_acc: 1.0000
# Epoch 33/50
# 5/5 [==============================] - 0s 69ms/step - loss: 4.0325e-06 - acc: 1.0000 - val_loss: 1.6038e-05 - val_acc: 1.0000
# Epoch 34/50
# 5/5 [==============================] - 0s 64ms/step - loss: 3.9711e-06 - acc: 1.0000 - val_loss: 1.5820e-05 - val_acc: 1.0000
# Epoch 35/50
# 5/5 [==============================] - 0s 65ms/step - loss: 3.9101e-06 - acc: 1.0000 - val_loss: 1.5624e-05 - val_acc: 1.0000
# Epoch 36/50
# 5/5 [==============================] - 0s 70ms/step - loss: 3.8691e-06 - acc: 1.0000 - val_loss: 1.5413e-05 - val_acc: 1.0000
# Epoch 37/50
# 5/5 [==============================] - 0s 66ms/step - loss: 3.8112e-06 - acc: 1.0000 - val_loss: 1.5223e-05 - val_acc: 1.0000
# Epoch 38/50
# 5/5 [==============================] - 0s 66ms/step - loss: 3.7751e-06 - acc: 1.0000 - val_loss: 1.5012e-05 - val_acc: 1.0000
# Epoch 39/50
# 5/5 [==============================] - 0s 68ms/step - loss: 3.7183e-06 - acc: 1.0000 - val_loss: 1.4823e-05 - val_acc: 1.0000
# Epoch 40/50
# 5/5 [==============================] - 0s 65ms/step - loss: 3.6822e-06 - acc: 1.0000 - val_loss: 1.4616e-05 - val_acc: 1.0000
# Epoch 41/50
# 5/5 [==============================] - 0s 69ms/step - loss: 3.6225e-06 - acc: 1.0000 - val_loss: 1.4441e-05 - val_acc: 1.0000
# Epoch 42/50
# 5/5 [==============================] - 0s 67ms/step - loss: 3.5851e-06 - acc: 1.0000 - val_loss: 1.4253e-05 - val_acc: 1.0000
# Epoch 43/50
# 5/5 [==============================] - 0s 68ms/step - loss: 3.5374e-06 - acc: 1.0000 - val_loss: 1.4076e-05 - val_acc: 1.0000
# Epoch 44/50
# 5/5 [==============================] - 0s 67ms/step - loss: 3.4954e-06 - acc: 1.0000 - val_loss: 1.3900e-05 - val_acc: 1.0000
# Epoch 45/50
# 5/5 [==============================] - 0s 67ms/step - loss: 3.4476e-06 - acc: 1.0000 - val_loss: 1.3740e-05 - val_acc: 1.0000
# Epoch 46/50
# 5/5 [==============================] - 0s 65ms/step - loss: 3.4092e-06 - acc: 1.0000 - val_loss: 1.3576e-05 - val_acc: 1.0000
# Epoch 47/50
# 5/5 [==============================] - 0s 64ms/step - loss: 3.3773e-06 - acc: 1.0000 - val_loss: 1.3395e-05 - val_acc: 1.0000
# Epoch 48/50
# 5/5 [==============================] - 0s 68ms/step - loss: 3.3250e-06 - acc: 1.0000 - val_loss: 1.3246e-05 - val_acc: 1.0000
# Epoch 49/50
# 5/5 [==============================] - 0s 67ms/step - loss: 3.2959e-06 - acc: 1.0000 - val_loss: 1.3076e-05 - val_acc: 1.0000
# Epoch 50/50
# 5/5 [==============================] - 0s 64ms/step - loss: 3.2540e-06 - acc: 1.0000 - val_loss: 1.2916e-05 - val_acc: 1.0000

# %% [markdown]
# <h3>Evaluasi Model</h3>

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, 50), H.history["val_loss"], label="val_loss")
plt.title("Loss Plot")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 50), H.history["acc"], label="train_acc")
plt.plot(np.arange(0, 50), H.history["val_acc"], label="val_acc")
plt.title("Accuracy Plot")
plt.xlabel("Epoch #")
plt.ylabel("Acc")
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report

pred = model.predict(x_val)
labels = (pred > 0.5).astype(np.int)

print(classification_report(y_val, labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#
#     accuracy                           1.00        10
#    macro avg       1.00      1.00      1.00        10
# weighted avg       1.00      1.00      1.00        10
